# %% [markdown]
# <a href="https://colab.research.google.com/github/narenp12/bayesian-causal-learning/blob/main/arXiv%20Ingestion" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("Cornell-University/arxiv")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'arxiv' dataset.
# Path to dataset files: /kaggle/input/arxiv
