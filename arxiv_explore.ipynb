# %% [markdown]
# # Exploration notebook of arxiv papers

# %%
import polars as pl
import plotly.express as px

# %%
pl.read_parquet_schema("arxiv_random_sample.parquet")
# Out:
# Schema([('id', String),
#         ('submitter', String),
#         ('authors', String),
#         ('title', String),
#         ('comments', String),
#         ('journal-ref', String),
#         ('doi', String),
#         ('report-no', String),
#         ('categories', String),
#         ('license', String),
#         ('abstract', String),
#         ('versions', List(Struct({'created': String, 'version': String}))),
#         ('update_date', String),
#         ('authors_parsed', List(List(String)))])

# %%
sample = pl.scan_parquet("arxiv_random_sample.parquet")

# %%
sample.null_count().collect()
# Out:
# shape: (1, 14)
# ┌─────┬───────────┬─────────┬───────┬───┬──────────┬──────────┬─────────────┬────────────────┐
# │ id  ┆ submitter ┆ authors ┆ title ┆ … ┆ abstract ┆ versions ┆ update_date ┆ authors_parsed │
# │ --- ┆ ---       ┆ ---     ┆ ---   ┆   ┆ ---      ┆ ---      ┆ ---         ┆ ---            │
# │ u32 ┆ u32       ┆ u32     ┆ u32   ┆   ┆ u32      ┆ u32      ┆ u32         ┆ u32            │
# ╞═════╪═══════════╪═════════╪═══════╪═══╪══════════╪══════════╪═════════════╪════════════════╡
# │ 0   ┆ 12166     ┆ 0       ┆ 0     ┆ … ┆ 0        ┆ 0        ┆ 0           ┆ 0              │
# └─────┴───────────┴─────────┴───────┴───┴──────────┴──────────┴─────────────┴────────────────┘

# %%
subset = sample.select((["id", "authors", "title", "categories", "abstract", "update_date"]))
